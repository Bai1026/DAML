# %% [markdown]
# # Handlinge the data processing with housing_data.ipynb

# %%
import os
import csv
import numpy as np
import pandas as pd
from copy import deepcopy

# %%
csv_file_path = './data/housing_data_raw.csv'

def load_csv(csv_file_path):
    ori_data = []
    with open(csv_file_path, mode='r', newline='') as file:
        reader = csv.reader(file)
        header = next(reader)  
        for row in reader:
            ori_data.append(row)

    df = pd.DataFrame(ori_data, columns=header)
    print(header)
    return df

df = load_csv(csv_file_path)

print(df.shape)
print(df.head(5))
# Out:
# ['Area', 'No. of Rooms', 'No. of Bathrooms', 'Location', 'Miles (dist. between school and house)', 'Rent Price per Month', 'Sell Price']
# (1000, 7)
#    Area No. of Rooms No. of Bathrooms Location  \
# 0  1360            1                1    Rural
# 1  1794            3                1   Suburb
# 2  1630            2                1   Suburb
# 3  1595            1                1   Suburb
# 4  2138            1                1   Suburb
#
#   Miles (dist. between school and house) Rent Price per Month Sell Price
# 0                                    463                 7401   74446632
# 1                                    210                 9259   76199794
# 2                                    157                16469   16249579
# 3                                    133                18096   24291317
# 4                                     10                 9923   50273384

# %% [markdown]
# - Check the data missing issue

# %%
print("DataFrame Information：")
print(df.info())
# Out:
# DataFrame Information：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Area                                    1000 non-null   object
#  1   No. of Rooms                            1000 non-null   object
#  2   No. of Bathrooms                        1000 non-null   object
#  3   Location                                1000 non-null   object
#  4   Miles (dist. between school and house)  1000 non-null   object
#  5   Rent Price per Month                    1000 non-null   object
#  6   Sell Price                              1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB
# None

# %% [markdown]
# - Check the unique values of the No. of bathrooms

# %%
unique_bathroom = df['No. of Bathrooms'].unique()
print(unique_bathroom)
df = df.drop('No. of Bathrooms', axis=1)
# Out:
# ['1']

# %% [markdown]
# - One-hot enceding the location for further usage
# - 'Rural': 0, 'Suburb': 1, 'City Center': 2

# %%
# Do one-hot enceding here for Location
mapping_dict = {}

unique_values = df['Location'].unique()
for i, value in enumerate(unique_values):
    mapping_dict[value] = i

df['Location'] = df['Location'].map(mapping_dict)

# use get_dummies function for one-hot encoding
one_hot_encoded_df = pd.get_dummies(df['Location'])

print(mapping_dict)
df.head(5)
# Out:
# {'Rural': 0, 'Suburb': 1, 'City Center': 2}
#    Area No. of Rooms  Location Miles (dist. between school and house)  \
# 0  1360            1         0                                    463
# 1  1794            3         1                                    210
# 2  1630            2         1                                    157
# 3  1595            1         1                                    133
# 4  2138            1         1                                     10
#
#   Rent Price per Month Sell Price
# 0                 7401   74446632
# 1                 9259   76199794
# 2                16469   16249579
# 3                18096   24291317
# 4                 9923   50273384

# %% [markdown]
# - Add the columns we want here
#     1. Rental Yield
#     2. Sell price per Area
#     3. Rent Price per Area

# %%
# Change all the info into float first
df = df.astype(float)

# Calculate the 'Rental Yield' and add it as a new column
# This is provided by: https://rich01.com/rental-yield-calculation/ 
df['Rental Yield (%)'] = ((df['Rent Price per Month']*12) / df['Sell Price']) * 100

df['Sell Price per Area'] = df['Sell Price'] / df['Area']
df['Rent Price per Area (monthly)'] = df['Rent Price per Month'] / df['Area']

df['Sell Price per Miles'] = df['Sell Price'] / df['Miles (dist. between school and house)']
df['Rent Price per Miles (monthly)'] = df['Rent Price per Month'] / df['Miles (dist. between school and house)']

df.head(5)
# Out:
#      Area  No. of Rooms  Location  Miles (dist. between school and house)  \
# 0  1360.0           1.0       0.0                                   463.0
# 1  1794.0           3.0       1.0                                   210.0
# 2  1630.0           2.0       1.0                                   157.0
# 3  1595.0           1.0       1.0                                   133.0
# 4  2138.0           1.0       1.0                                    10.0
#
#    Rent Price per Month  Sell Price  Rental Yield (%)  Sell Price per Area  \
# 0                7401.0  74446632.0          0.119296         54740.170588
# 1                9259.0  76199794.0          0.145811         42474.801561
# 2               16469.0  16249579.0          1.216204          9969.066871
# 3               18096.0  24291317.0          0.893949         15229.665831
# 4                9923.0  50273384.0          0.236857         23514.211413
#
#    Rent Price per Area (month)  Rent Price per Area (monthly)  \
# 0                     5.441912                       5.441912
# 1                     5.161093                       5.161093
# 2                    10.103681                      10.103681
# 3                    11.345455                      11.345455
# 4                     4.641254                       4.641254
#
#    Sell Price per Miles  Rent Price per Miles (monthly)
# 0          1.607919e+05                       15.984881
# 1          3.628562e+05                       44.090476
# 2          1.035005e+05                      104.898089
# 3          1.826415e+05                      136.060150
# 4          5.027338e+06                      992.300000

# %%
average_prices_by_location = df.groupby('Location')['Sell Price'].mean()
average_rent_by_location = df.groupby('Location')['Rent Price per Month'].mean()
rental_yield_by_location = df.groupby('Location')['Rental Yield (%)'].mean()

print("Average Sell Prices by Location:\n", average_prices_by_location)
print("\nAverage Rent Prices by Location:\n", average_rent_by_location)
print("\nAverage Rental Yield by Location:\n", rental_yield_by_location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 average_prices_by_location = df.groupby('Location')['Sell Price'].mean()
#       2 average_rent_by_location = df.groupby('Location')['Rent Price per Month'].mean()
#       3 rental_yield_by_location = df.groupby('Location')['Rental Yield (%)'].mean()
#
# NameError: name 'df' is not defined

# %%
df.head(2)
# Out:
#      Area  No. of Rooms  Location  Miles (dist. between school and house)  \
# 0  1360.0           1.0       0.0                                   463.0
# 1  1794.0           3.0       1.0                                   210.0
#
#    Rent Price per Month  Sell Price  Rental Yield (%)  Sell Price per Area  \
# 0                7401.0  74446632.0          0.119296         54740.170588
# 1                9259.0  76199794.0          0.145811         42474.801561
#
#    Rent Price per Area (month)  Rent Price per Area (monthly)  \
# 0                     5.441912                       5.441912
# 1                     5.161093                       5.161093
#
#    Sell Price per Miles  Rent Price per Miles (monthly)
# 0         160791.861771                       15.984881
# 1         362856.161905                       44.090476

# %% [markdown]
# ## ML Prediction Part

# %%
# 使用線性回歸分析房間數量和浴室數量與售價之間的關係
from sklearn.linear_model import LinearRegression

# 設定自變量X和因變量y
# X = df[['No. of Rooms', 'Area', 'Miles (dist. between school and house)']]
# X = df[['No. of Rooms', 'Area', 'Location', 'Miles (dist. between school and house)']]
X = df[['No. of Rooms', 'Location']]
y = df['Sell Price']

# 建立線性回歸模型
model = LinearRegression()
model.fit(X, y)

print("Coefficients for No. of Rooms, Area, Location, Miles with sell price:\n", model.coef_)
#  41452289.76207246 41452289.76207246 41726791.07677385 42703450.22107105
#  43680109.36536825 43680109.36536825 42703450.22107105 41452289.76207246
#  40475630.61777525 42077869.99157175 40475630.61777525 40475630.61777525
#  43680109.36536825 42428948.90636966 43680109.36536825 43054529.13586895
#  42077869.99157175 42428948.90636966 42077869.99157175 42428948.90636966
#  42077869.99157175 41726791.07677385 42703450.22107105 42703450.22107105
#  43680109.36536825 41452289.76207246 41101210.84727455 40475630.61777525
#  43680109.36536825 40475630.61777525 42077869.99157175 40475630.61777525
#  43054529.13586895 41452289.76207246 43054529.13586895 42077869.99157175
#  41726791.07677385 43054529.13586895 43680109.36536825 42703450.22107105
#  43680109.36536825 41452289.76207246 41452289.76207246 41452289.76207246
#  41452289.76207246 41101210.84727455 42077869.99157175 42428948.90636966
#  41101210.84727455 43054529.13586895 41726791.07677385 42703450.22107105
#  41726791.07677385 41726791.07677385 43054529.13586895 42428948.90636966
#  42077869.99157175 41101210.84727455 41101210.84727455 41726791.07677385
#  42703450.22107105 42703450.22107105 41452289.76207246 42077869.99157175
#  41452289.76207246 43680109.36536825 40475630.61777525 41101210.84727455
#  41101210.84727455 41726791.07677385 41726791.07677385 40475630.61777525
#  41726791.07677385 41726791.07677385 43054529.13586895 41726791.07677385
#  43680109.36536825 42077869.99157175 41101210.84727455 41452289.76207246
#  42703450.22107105 42077869.99157175 42428948.90636966 41452289.76207246
#  42703450.22107105 42703450.22107105 40475630.61777525 41101210.84727455
#  42428948.90636966 43680109.36536825 41101210.84727455 43054529.13586895
#  40475630.61777525 42703450.22107105 41452289.76207246 42428948.90636966
#  40475630.61777525 41101210.84727455 43054529.13586895 41726791.07677385
#  42703450.22107105 42428948.90636966 42428948.90636966 40475630.61777525]

# %% [markdown]
# - Try to normalization the values

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# 假定df是你的DataFrame，且已經計算好了售價和租金

# 定義一個標準化器
scaler = StandardScaler()

# 假設df只包含要標準化的數值欄位
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# 顯示前五行數據
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 10
#       7 scaler = StandardScaler()
#       9 # 假設df只包含要標準化的數值欄位
# ---> 10 numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
#      11 df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
#      13 # 顯示前五行數據
#
# AttributeError: 'StandardScaler' object has no attribute 'select_dtypes'

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your DataFrame with all numerical columns
scaler = MinMaxScaler()

# Selecting columns to scale, typically you wouldn't scale one-hot encoded columns
columns_to_scale = ['Area', 'No. of Rooms', 'No. of Bathrooms', 'Miles (dist. between school and house)', 'Rent Price per Month', 'Sell Price']
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Now df is normalized and you can proceed with further analysis or model training
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 8
#       6 # Selecting columns to scale, typically you wouldn't scale one-hot encoded columns
#       7 columns_to_scale = ['Area', 'No. of Rooms', 'No. of Bathrooms', 'Miles (dist. between school and house)', 'Rent Price per Month', 'Sell Price']
# ----> 8 df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
#      10 # Now df is normalized and you can proceed with further analysis or model training
#      11 df
#
# TypeError: 'StandardScaler' object is not subscriptable

# %%
import matplotlib.pyplot as plt

# Predicting the Sell Price using the model
y_pred = model.predict(X)

# Plotting the actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y, y_pred, alpha=0.5)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)  # Diagonal line
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted Sell Prices')
plt.show()

# %%
# 使用線性回歸分析房間數量和浴室數量與售價之間的關係
from sklearn.linear_model import LinearRegression

# 設定自變量X和因變量y
X = df[['No. of Rooms', 'Area', 'Location', 'Miles (dist. between school and house)']]
# X = df[['No. of Rooms', 'Area', 'Miles (dist. between school and house)']]
y = df['Rent Price per Month']

# 建立線性回歸模型
model = LinearRegression()
model.fit(X, y)

print("Coefficients for No. of Rooms, Area, Miles with rental price:\n", model.coef_)
# Out:
# Coefficients for No. of Rooms, Area, Miles with rental price:
#  [ 84.65055671  -0.20523783 103.8295492   -1.69908593]

# %%
# Convert numerical columns from strings to floats using `pd.to_numeric()`
df['Rent Price per Month'] = pd.to_numeric(df['Rent Price per Month'], errors='coerce')
df['Sell Price'] = pd.to_numeric(df['Sell Price'], errors='coerce')
df['Miles (dist. between school and house)'] = pd.to_numeric(df['Miles (dist. between school and house)'], errors='coerce')

# Drop rows with NaN values that resulted from conversion errors
df = df.dropna(subset=['Rent Price per Month', 'Sell Price', 'Miles (dist. between school and house)'])

# %%
# 計算距離與售價之間的相關係數
correlation_distance_sell = df['Miles (dist. between school and house)'].corr(df['Sell Price'])
print("Correlation between Distance and Sell Price: ", correlation_distance_sell)

# 計算距離與租金之間的相關係數
correlation_distance_sell = df['Miles (dist. between school and house)'].corr(df['Rent Price per Month'])
print("Correlation between Distance and Rent Price per Month: ", correlation_distance_sell)
# Out:
# Correlation between Distance and Sell Price:  0.08143404772457158
# Correlation between Distance and Rent Price per Month:  -0.05843414142394175

# %%
import matplotlib.pyplot as plt

# 繪製租金和售價的直方圖
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(df['Sell Price'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Sell Prices')
plt.xlabel('Sell Price')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(df['Rent Price per Month'], bins=20, color='green', edgecolor='black')
plt.title('Distribution of Rent Prices')
plt.xlabel('Rent Price per Month')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# 計算年投資回報率，假設租金為穩定收入
df['Annual ROI (%)'] = df['Rental Yield (%)'] * 12
df['Annual ROI (%)'].head(10)
# Out:
# 0     1.431554
# 1     1.749737
# 2    14.594446
# 3    10.727389
# 4     2.842283
# 5    19.859387
# 6     2.036451
# 7     4.772563
# 8     6.337797
# 9     4.437408
# Name: Annual ROI (%), dtype: float64

# %%
header = ['Area', 'No. of Rooms', 'No. of Bathrooms', 'Location', 'Miles (dist. between school and house)', 'Rent Price per Month', 'Sell Price']
header.append('Rental Yield')
data = deepcopy(ori_data)
# print(data[:2])
updated_data = []

for row in data:
    print(row)
    rent_price = float(row[5])
    sell_price = float(row[6])
    rental_rate = (rent_price / sell_price) * 100  # 转换为百分比
    row.append(rental_rate)
    updated_data.append(row)
    break

print(header[5])
updated_data[:2]
# Out:
# ['1360', '1', '1', 'Rural', '463', '7401', '74446632']
# Rent Price per Month
# [['1360', '1', '1', 'Rural', '463', '7401', '74446632', 0.009941349663743014]]
